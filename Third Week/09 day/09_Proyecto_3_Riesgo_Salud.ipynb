# %% [markdown]
# # Proyecto Integrador 3: Predicción de Riesgo de Enfermedades (Salud)
#
# Este cuaderno representa la evaluación final. Se requiere construir un modelo de Clasificación Binaria capaz de predecir si un paciente padece una enfermedad cardíaca basándose en sus registros médicos.
#
# ## Contexto de Negocio / Clínico
# Un hospital líder busca optimizar sus diagnósticos preventivos. Los médicos registran datos como la presión sanguínea, nivel de colesterol, dolor de pecho y edad. El objetivo es que la Inteligencia Artificial analice estos parámetros y alerte si el paciente está en riesgo inminente de sufrir un infarto, permitiendo la intervención médica temprana.
#
# ---
# ### **Fase 1: Carga de Datos y Comprensión**

# %%
# Importación de librerías base
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Se utiliza el dataset Heart Disease de UCI Machine Learning
url = 'https://raw.githubusercontent.com/kb22/Heart-Disease-Prediction/master/dataset.csv'
df = pd.read_csv(url)
display(df.head())

# %% [markdown]
# **Diccionario de Datos Principal:**
# *   `age`: Edad del paciente.
# *   `sex`: Sexo (1 = Hombre, 0 = Mujer).
# *   `cp`: Tipo de dolor de pecho (0 a 3).
# *   `trestbps`: Presión arterial en reposo.
# *   `chol`: Colesterol sérico en mg/dl.
# *   `target`: Diagnóstico (1 = Presencia de enfermedad cardíaca, 0 = Sano).
#
# #### 📝 Tarea 1.1: Definición del Objetivo
# *(Redacte en esta celda cuál es la variable objetivo y por qué su correcta predicción es cuestión de vida o muerte)*
#
# [Escriba su respuesta aquí]

# %% [markdown]
# ---
# ### **Fase 2: Limpieza y Transformación (Data Munging)**
# Los datos médicos pueden tener sesgos o valores atípicos. Se requiere garantizar la calidad matemática del dataset.
#
# #### 📝 Tarea 2.1: Limpieza, División y Escalado
# *(Revise si hay nulos, separe el dataset (train/test), y OBLIGATORIAMENTE escale las variables numéricas como colesterol o presión, ya que modelos como k-NN son altamente sensibles a la escala)*

# %%
# TODO: Separar las características (X) y el objetivo (target)
# TODO: Ejecutar train_test_split (stratify=y es altamente recomendado en salud)
# TODO: Instanciar StandardScaler y escalar las variables de entrenamiento y prueba

# %% [markdown]
# ---
# ### **Fase 3: Análisis Exploratorio (EDA) y Consultas**
# Demuestre comprensión clínica de los datos a través de gráficas.
#
# #### 📝 Tarea 3.1: Consultas y Gráficos
# 1. Crear una consulta (Query) para encontrar cuántos pacientes menores de 50 años tienen enfermedad cardíaca (target=1).
# 2. Generar un Histograma múltiple comparando la `age` (edad) separada por la variable `target`.
# 3. Generar una Matriz de Correlación (Heatmap) para descubrir qué variable médica tiene mayor impacto en el `target`.
# 4. Explicar los hallazgos visuales.

# %%
# TODO: Escribir el código para las consultas y gráficos requeridos

# %% [markdown]
# #### Interpretación del EDA:
# [Explique aquí qué variable parece ser el mejor indicador de la enfermedad según su matriz de correlación]

# %% [markdown]
# ---
# ### **Fase 4: Comparativa de Modelos**
# Se exige implementar y comparar el rendimiento de DOS algoritmos radicalmente distintos.
#
# #### 📝 Tarea 4.1: k-NN vs Árbol de Decisión
# *(Entrene ambos modelos. Se evaluará positivamente si intenta iterar para encontrar el mejor número de vecinos 'K' en k-NN o la mejor profundidad 'max_depth' en el Árbol).*

# %%
# TODO: Importar KNeighborsClassifier y DecisionTreeClassifier
# TODO: Entrenar el Modelo k-NN y calcular su precisión/recall
# TODO: Entrenar el Modelo de Árbol y calcular su precisión/recall

# %% [markdown]
# ---
# ### **Fase 5: Interpretación de Resultados y Defensa Analítica**
# Esta es la fase crítica donde el estudiante actúa como el Científico Principal frente a la Junta Médica del Hospital.
#
# #### 📝 Tarea 5.1: Matriz de Confusión
# *(Genere la Matriz de Confusión para el modelo que haya decidido que es mejor)*

# %%
# TODO: Imprimir el classification_report del modelo seleccionado
# TODO: Graficar la Matriz de Confusión usando Seaborn o ConfusionMatrixDisplay

# %% [markdown]
# #### 📝 Tarea 5.2: Defensa Analítica (Ética Médica)
# Con base en la matriz de confusión generada:
#
# 1. **Impacto Clínico:** En el diagnóstico del corazón:
#    * ¿Qué significa un Falso Positivo? (El modelo indica que el paciente está enfermo, pero realmente está sano).
#    * ¿Qué significa un Falso Negativo? (El modelo indica que el paciente está sano, pero realmente tiene el corazón dañado).
# 2. **Decisión Final:** ¿Qué tipo de error es vitalmente peor en la medicina? Según la respuesta analítica, ¿qué métrica estadística (Accuracy, Precision, o Recall/Sensibilidad) se debe intentar llevar al 100% sin importar que las otras métricas bajen un poco?
#
# **Respuesta del Estudiante:**
#
# [Redacte su defensa clínica y ética aquí, justificando su postura frente a la junta médica]
