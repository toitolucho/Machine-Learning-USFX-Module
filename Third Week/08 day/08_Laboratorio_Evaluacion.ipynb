# %% [markdown]
# # Módulo 4: Machine Learning en la Industria
# ## Laboratorio de Evaluación: Día 08 (Mega-Pipeline)
#
# Este laboratorio representa el reto final antes del Proyecto Integrador. El objetivo es aplicar los conocimientos sobre la construcción de Pipelines industriales para evitar la fuga de datos (Data Leakage) y optimizar modelos predictivos desde cero.
#
# ### **El Reto de Negocio: Campañas de Marketing Bancario**
# En este escenario, el estudiante actuará como el Científico de Datos Principal de un Banco Europeo. El equipo de Marketing invierte altas sumas de dinero en campañas telefónicas para ofrecer un nuevo "Depósito a Plazo Fijo". Sin embargo, la inmensa mayoría de las llamadas son rechazadas.
#
# **Misión:** Se requiere construir un Mega-Pipeline que prediga, basándose en la edad, trabajo, estado civil y préstamos anteriores del cliente, si este aceptará o rechazará la oferta (Variable Objetivo: `deposit`). Si el modelo presenta un desempeño adecuado, el banco contactará exclusivamente a los clientes con alta probabilidad de suscripción, ahorrando significativos costos operativos.

# %%
# Importación de Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import joblib

# %%
# Carga de Datos Oficiales
# Se extrae el dataset clásico de Telemarketing Bancario directamente desde un repositorio de Github confiable.
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/bank.csv'
df = pd.read_csv(url, sep=';') # Nota: Este dataset en particular usa punto y coma como separador

# La variable objetivo es 'y' (yes/no). Se convertirá en 1 (Sí suscribió) y 0 (No).
df['objetivo'] = df['y'].apply(lambda x: 1 if x == 'yes' else 0)
df = df.drop(columns=['y'])

display(df.head())
print("Forma del dataset:", df.shape)

# %% [markdown]
# ---
# ### **Paso 1: Evitar el Data Leakage (División de Datos)**
# Se deben separar los datos en el conjunto de Entrenamiento (80%) y el conjunto de Pruebas/Examen (20%).

# %%
# TODO: Extraer las características (X) y el objetivo (y)
# X = ...
# y = ...

# TODO: Aplicar train_test_split. Se recomienda usar stratify=y debido al desbalanceo de clases.
# X_train, X_test, y_train, y_test = ...

# %% [markdown]
# ---
# ### **Paso 2: La Sala de Máquinas (ColumnTransformer)**
# Se deben identificar qué columnas son de texto (Categóricas) y cuáles son numéricas. Posteriormente, se construirá el Mega-Transformador.

# %%
# TODO: Seleccionar automáticamente las columnas numéricas y categóricas basándose en X_train
# cols_numericas = ...
# cols_categoricas = ...

# TODO: Crear el pipeline_numerico (Debe imputar medianas y escalar datos)
# pipeline_numerico = Pipeline(steps=[...])

# TODO: Crear el pipeline_categorico (Debe imputar 'most_frequent' y aplicar OneHotEncoder(handle_unknown='ignore'))
# pipeline_categorico = Pipeline(steps=[...])

# TODO: Unir ambas tuberías usando ColumnTransformer
# preprocesador = ColumnTransformer(transformers=[...])

# %% [markdown]
# ---
# ### **Paso 3: Ensamblaje del Algoritmo y Entrenamiento**
# Se unirá el Preprocesador con el Algoritmo Predictivo en un Pipeline final para su posterior entrenamiento.

# %%
# TODO: Construir el mega_pipeline conectando el 'preprocesador' y un RandomForestClassifier
# IMPORTANTE: Usar class_weight='balanced' dentro del modelo.
# mega_pipeline = Pipeline(steps=[...])

# TODO: (Opcional) Optimizar mega_pipeline en un GridSearchCV.
# En caso contrario, entrenar el mega_pipeline directamente.

# TODO: Entrenar el modelo (Asegurarse de pasar solo X_train e y_train para evitar Data Leakage)
# mega_pipeline.fit(X_train, y_train)

# %% [markdown]
# ---
# ### **Paso 4: Examen Final y Decisión de Negocio**
# El modelo debe realizar predicciones sobre los datos de prueba (`X_test`) para imprimir el reporte final de desempeño.

# %%
# TODO: Extraer predicciones de X_test
# predicciones = ...

# TODO: Imprimir el classification_report y mostrar la ConfusionMatrixDisplay
# print(classification_report(...))
# disp = ConfusionMatrixDisplay(...)

# %% [markdown]
# ### 📝 Evaluación Teórica de Negocios (Decisión Final)
# Con base en la matriz de confusión generada, se presentan las siguientes premisas:
# 1. Cada llamada al Call Center representa un costo operativo de $5.
# 2. Cada cliente que acepta el depósito bancario genera una ganancia de $500.
#
# **Pregunta de Negocio:** Desde una perspectiva financiera, ¿es preferible que el modelo incurra en Falsos Positivos (contactar a un cliente que rechazará la oferta) o en Falsos Negativos (omitir a un cliente que habría aceptado la oferta)? Se requiere justificar la decisión analíticamente.
#
# *(Doble clic aquí para escribir la respuesta analítica)*

# %%
# TODO: Usar joblib para exportar el mega_pipeline completo a un archivo llamado 'pipeline_bancario_produccion.pkl'
# joblib.dump(...)
